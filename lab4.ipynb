# %% [markdown]
# Lab 4
# Python Lists
# 1. Write a Python Program to print all the items in a list.
# 2. Use range function to print all the even numbers from 1 to 10.
# 3. Write a Python Program to get the largest and smallest number in a list without using builtin functions.
# 4. Write a Python program to find the second smallest and second largest numbers in a list.
# 5. Write a Python program to sum all the items in a list.
# 6. Write a Python program to multiply all the items in a list.
# 7. Write a Python program to check if a list is empty or not.
# 8. Write a Python program to print the numbers of a specified list after removing even
# numbers from it.
# 9. Write a Python Program to print a specified list after removing the 0th, 4th and 5th element.
# Sample list: [‘Red’, ‘Green’, ‘White’, ‘Black’, ‘Pink’, ‘Yellow’]
# Expected Output: [‘Green’, ‘White’, ‘Black’]
# 10.Write a Python Program to check if each number is prime in a given list of numbers. Print
# the prime numbers if any, otherwise print “no prime numbers”.
# 11.Write a Python program to remove duplicates from a list.
# 12.Write a Python Program to merge two lists and removes all duplicates from the combined
# list.
# 13.Write a Python Program to print a list in a reverse order.
# 14.Write a Python program to sort a given list of strings (numbers) numerically.
# Original list:
# ['4', '12', '45', '7', '0', '100', '200', '-12', '-500']
# Sort the said list of strings(numbers) numerically:
# [-500, -12, 0, 4, 7, 12, 45, 100, 200]
# 15.Apply various functions like append, remove, pop, insert, sort, max, min in a list.
# 16.Write a python program to copy a content of one list to another.
# 17.Write a Python Program to sort a list of lists by a given index of the inner list.
# 18.Write a Python program to generate and print a list of the first and last 5 elements where
# the values are square numbers between 1 and 15 (both included).
# 19.Write a Python program to insert a given string at the beginning of all items in a list.
# Sample list : [1,2,3,4], string : emp
# Expected output : ['emp1', 'emp2', 'emp3', 'emp4']
# 20.Write a Python program to insert n values in a list and find those values in a list that are
# greater than a specified number.

# %% [markdown]
# Write a Python Program to print all the items in a list.

# %%
mylist = ["apple", "banana", "cherry", 1, 2, True]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry', 1, 2, True]

# %% [markdown]
# Use range function to print all the even numbers from 1 to 10

# %%
mylist = range(1,10+1)
for x in range (len(mylist)):
  if mylist[x] % 2 == 0 :
   print(mylist[x], end = " ")
# Out:
# 2 4 6 8 10

# %% [markdown]
# Write a Python Program to get the largest and smallest number in a list without using builtin functions.

# %%
mylist = [12,24,3,45,7]
# mylist.sort()
# print("The largest is  :", mylist[-1])
# print("The smallest is :", mylist[0])

largest=mylist[0]
smallest=mylist[0]
for i in mylist:
  if i>largest:
    largest=i
  if i<smallest:
    smallest=i
print("largest number:",largest)
print("smallest number:",smallest)
# Out:
# largest number: 45
# smallest number: 3

# %%
mylist = [12,24,3,45,7]
mylist.sort()
print("The second largest is  :", mylist[-2])
print("The second smallest is :", mylist[1])

# for x in range (len(mylist)):
#   if mylist[x] > mylist[x+1]:
#     large = my
# Out:
# The largest is  : 24
# The smallest is : 7

# %%
mylist = [12,24,3,45,7]
sum = 0
for x in range (len(mylist)):
  sum = sum + mylist[x]
print("The sum of the elements in the lis is ", sum)
# Out:
# The sum of the elements in the lis is  91

# %%
mylist = [12,24,3,45,7]
pro = 1
for x in range (len(mylist)):
  pro = pro * mylist[x]
print("The product of the elements in the lis is ", pro)
# Out:
# The product of the elements in the lis is  272160

# %%
list1 = []
if not list1:
    print("The list is empty")
else:
    print("The list is not empty")
# Out:
# The list is empty

# %% [markdown]
# Write a Python program to print the numbers of a specified list after removing even numbers from it.

# %%
for mylist in range (10):
  if mylist % 2 == 0:
    continue
  else:
    print(mylist)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# Write a Python Program to print a specified list after removing the 0th, 4th and 5th element. Sample list: [‘Red’, ‘Green’, ‘White’, ‘Black’, ‘Pink’, ‘Yellow’] Expected Output: [‘Green’, ‘White’, ‘Black’]

# %%
list = ["Red","Green","White","Black","Pink","Yellow"]
list.remove(list[0])
list.remove(list[3])
list.remove(list[3])
print(list)
# Out:
# ['Green', 'White', 'Black']

# %%
list1 = [5,7,13]
count = 1
for x in range (1,len(list1)):
  for y in range (1,list[x]):
   if list1 [x] % y == 0 :
    count = count + 1
    print(count)
if count == 2:
  print("Yes")
else:
  print("No")

# list = 9
# count = 1
# for x in range (1,list):
#   if list % x == 0 :
#     count = count + 1
# if count == 2:
#   print("Yes")
# else:
#   print("No")
# Out:
# 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-e324685f26e9> in <cell line: 3>()
#       2 count = 1
#       3 for x in range (1,len(list1)):
# ----> 4   for y in range (1,list[x]):
#       5    if list1 [x] % y == 0 :
#       6     count = count + 1
#
# IndexError: list index out of range

# %%
list1 = [5,7,13]
count = 1
for x in range (1,len(list1)):
  # the variable list has been reassigned to a two-element list
  # for y in range (1,list[x]):
  for y in range (1,list1[x]): # use list1 instead of list
    if list1 [x] % y == 0 :
      count = count + 1
      print(count)
if count == 2:
  print("Yes")
else:
  print("No")

# list = 9
# count = 1
# for x in range (1,list):
#   if list % x == 0 :
#     count = count + 1
# if count == 2:
#   print("Yes")
# else:
#   print("No")
# Out:
# 2
# 3
# No

# %%
numbers = [int(x) for x in input("Enter a list of numbers separated by spaces: ").split()]

primes = []
for num in numbers:
  if num > 1:
    is_prime = True
    for i in range(2, int(num**0.5) + 1):
      if num % i == 0:
        is_prime = False
        break
    if is_prime:
      primes.append(num)

if primes:
  print("Prime numbers:", primes)
else:
  print("no prime numbers")
# Out:
# Enter a list of numbers separated by spaces: 1 3
# Prime numbers: [3]

# %% [markdown]
# Write a Python Program to check if each number is prime in a given list of numbers. Print the prime numbers if any, otherwise print “no prime numbers”.

# %% [markdown]
# Write a Python program to remove duplicates from a list.

# %%
mylist = [1,2,4,2,3,4]
x = 0
while x < len(mylist):
  y = x + 1
  while y < len(mylist):
    if mylist[x] == mylist[y]:
      del mylist[y]
    else:
      y += 1
  x += 1
print(mylist)
# Out:
# [1, 2, 4, 3]

# %% [markdown]
# Write a Python program to insert a given string at the beginning of all items in a list. Sample list : [1,2,3,4], string : emp Expected output : ['emp1', 'emp2', 'emp3', 'emp4']

# %%
mylist = [1,2,3,4]
for x in range (1,len(mylist)+1):
  print(f"emp{x}")
# Out:
# emp1
# emp2
# emp3
# emp4

# %%
mylist = [1,2,3]
mylist.append(4)
print(mylist)
mylist.remove(4)
print(mylist)
mylist.pop()
print(mylist)
mylist.insert(0,5)
print(mylist)
mylist.sort()
print(mylist)
print(max(mylist))
print(min(mylist))
# Out:
# [1, 2, 3, 4]
# [1, 2, 3]
# [1, 2]
# [5, 1, 2]
# [1, 2, 5]
# 5
# 1

# %%
mylist = [[1,2,4,2,5,88],[3,24,255,6,76]]
mylist[1].sort()
print(mylist[1])
# Out:
# [3, 6, 24, 76, 255]

# %%
mylist = ['4', '12', '45', '7', '0', '100', '200', '-12', '-500']
# mylist.sort()
# print(mylist)
newlist = []
for x in range (len(mylist)):
    newlist.append(mylist[x])
print(newlist)
newlist.sort()
print(newlist)
# Out:
# ['4', '12', '45', '7', '0', '100', '200', '-12', '-500']
# ['-12', '-500', '0', '100', '12', '200', '4', '45', '7']

# %%
# Get input from the user
n = int(input("Enter the number of values: "))
num = int(input("Enter the number to compare against: "))

# Create an empty list and insert n values
mylist = []
for i in range(n):
  value = int(input(f"Enter value {i+1}: "))
  mylist.append(value)

# Find values greater than num
greater_than = [value for value in mylist if value > num]
print("Values greater than", num, "are:", greater_than)
# Out:
# Enter the number of values: 4
# Enter the number to compare against: 43
# Enter value 1: 12
# Enter value 2: 34
# Enter value 3: 67
# Enter value 4: 89
# Values greater than 43 are: [67, 89]
